# %% [markdown]
# # **Limpieza de datos**

# %%
install.packages("arrow")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘assertthat’

# %%
#Librerias necesarias
library(ggplot2)
library(dplyr)
library(arrow)
library(lubridate)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
#
# Attaching package: ‘lubridate’
#
#
# The following object is masked from ‘package:arrow’:
#
#     duration
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
historicos <- read_parquet('https://geronimofretes.github.io/infovis/data/precios_historicos.parquet')

# %%
colnames(historicos)
# Out:
#  [1] "idempresa"        "empresa"          "direccion"        "localidad"
#  [5] "provincia"        "idproducto"       "producto"         "idtipohorario"
#  [9] "tipohorario"      "precio"           "fecha_vigencia"   "idempresabandera"
# [13] "empresabandera"   "latitud"          "longitud"         "geojson"

# %%
str(historicos)
# Out:
# tibble [2,854,281 × 16] (S3: tbl_df/tbl/data.frame)
#  $ idempresa       : int [1:2854281] 1376 1376 1376 1376 1376 1376 1376 1376 1376 1376 ...
#  $ empresa         : chr [1:2854281] "10 DE SETIEMBRE S.A." "10 DE SETIEMBRE S.A." "10 DE SETIEMBRE S.A." "10 DE SETIEMBRE S.A." ...
#  $ direccion       : chr [1:2854281] "Av. Mosconi 299" "Av. Mosconi 299" "Av. Mosconi 299" "Av. Mosconi 299" ...
#  $ localidad       : chr [1:2854281] "LOMAS DEL MIRADOR" "LOMAS DEL MIRADOR" "LOMAS DEL MIRADOR" "LOMAS DEL MIRADOR" ...
#  $ provincia       : chr [1:2854281] "BUENOS AIRES" "BUENOS AIRES" "BUENOS AIRES" "BUENOS AIRES" ...
#  $ idproducto      : int [1:2854281] 19 19 19 19 19 19 19 19 19 19 ...
#  $ producto        : chr [1:2854281] "Gas Oil Grado 2" "Gas Oil Grado 2" "Gas Oil Grado 2" "Gas Oil Grado 2" ...
#  $ idtipohorario   : int [1:2854281] 2 3 2 3 2 3 2 3 2 3 ...
#  $ tipohorario     : chr [1:2854281] "Diurno" "Nocturno" "Diurno" "Nocturno" ...
#  $ precio          : num [1:2854281] 985 985 1080 1080 1108 ...
#  $ fecha_vigencia  : chr [1:2854281] "01/04/2024 10:11" "01/04/2024 10:11" "01/07/2024 09:43" "01/07/2024 09:43" ...
#  $ idempresabandera: int [1:2854281] 28 28 28 28 28 28 28 28 28 28 ...
#  $ empresabandera  : chr [1:2854281] "PUMA" "PUMA" "PUMA" "PUMA" ...
#  $ latitud         : num [1:2854281] -34.7 -34.7 -34.7 -34.7 -34.7 ...
#  $ longitud        : num [1:2854281] -58.5 -58.5 -58.5 -58.5 -58.5 ...
#  $ geojson         : chr [1:2854281] "{\"type\":\"Point\",\"coordinates\":[-58.529443,-34.658476]}" "{\"type\":\"Point\",\"coordinates\":[-58.529443,-34.658476]}" "{\"type\":\"Point\",\"coordinates\":[-58.529443,-34.658476]}" "{\"type\":\"Point\",\"coordinates\":[-58.529443,-34.658476]}" ...

# %%
head(historicos)
# Out:
#   idempresa empresa              direccion       localidad         provincia
# 1 1376      10 DE SETIEMBRE S.A. Av. Mosconi 299 LOMAS DEL MIRADOR BUENOS AIRES
# 2 1376      10 DE SETIEMBRE S.A. Av. Mosconi 299 LOMAS DEL MIRADOR BUENOS AIRES
# 3 1376      10 DE SETIEMBRE S.A. Av. Mosconi 299 LOMAS DEL MIRADOR BUENOS AIRES
# 4 1376      10 DE SETIEMBRE S.A. Av. Mosconi 299 LOMAS DEL MIRADOR BUENOS AIRES
# 5 1376      10 DE SETIEMBRE S.A. Av. Mosconi 299 LOMAS DEL MIRADOR BUENOS AIRES
# 6 1376      10 DE SETIEMBRE S.A. Av. Mosconi 299 LOMAS DEL MIRADOR BUENOS AIRES
#   idproducto producto        idtipohorario tipohorario precio fecha_vigencia
# 1 19         Gas Oil Grado 2 2             Diurno       985   01/04/2024 10:11
# 2 19         Gas Oil Grado 2 3             Nocturno     985   01/04/2024 10:11
# 3 19         Gas Oil Grado 2 2             Diurno      1080   01/07/2024 09:43
# 4 19         Gas Oil Grado 2 3             Nocturno    1080   01/07/2024 09:43
# 5 19         Gas Oil Grado 2 2             Diurno      1108   01/08/2024 13:40
# 6 19         Gas Oil Grado 2 3             Nocturno    1108   01/08/2024 13:40
#   idempresabandera empresabandera latitud   longitud
# 1 28               PUMA           -34.65848 -58.52944
# 2 28               PUMA           -34.65848 -58.52944
# 3 28               PUMA           -34.65848 -58.52944
# 4 28               PUMA           -34.65848 -58.52944
# 5 28               PUMA           -34.65848 -58.52944
# 6 28               PUMA           -34.65848 -58.52944
#   geojson
# 1 {"type":"Point","coordinates":[-58.529443,-34.658476]}
# 2 {"type":"Point","coordinates":[-58.529443,-34.658476]}
# 3 {"type":"Point","coordinates":[-58.529443,-34.658476]}
# 4 {"type":"Point","coordinates":[-58.529443,-34.658476]}
# 5 {"type":"Point","coordinates":[-58.529443,-34.658476]}
# 6 {"type":"Point","coordinates":[-58.529443,-34.658476]}

# %%
tail(historicos)
# Out:
#   idempresa empresa     direccion       localidad     provincia    idproducto
# 1 4097      ZUSICO S.A. TALCAHUANO 1198 MAR DEL PLATA BUENOS AIRES 2
# 2 4097      ZUSICO S.A. TALCAHUANO 1198 MAR DEL PLATA BUENOS AIRES 2
# 3 4097      ZUSICO S.A. TALCAHUANO 1198 MAR DEL PLATA BUENOS AIRES 2
# 4 4097      ZUSICO S.A. TALCAHUANO 1198 MAR DEL PLATA BUENOS AIRES 2
# 5 4097      ZUSICO S.A. TALCAHUANO 1198 MAR DEL PLATA BUENOS AIRES 2
# 6 4097      ZUSICO S.A. TALCAHUANO 1198 MAR DEL PLATA BUENOS AIRES 2
#   producto                        idtipohorario tipohorario precio
# 1 Nafta (súper) entre 92 y 95 Ron 2             Diurno       46.37
# 2 Nafta (súper) entre 92 y 95 Ron 3             Nocturno     46.37
# 3 Nafta (súper) entre 92 y 95 Ron 2             Diurno       46.21
# 4 Nafta (súper) entre 92 y 95 Ron 3             Nocturno     46.21
# 5 Nafta (súper) entre 92 y 95 Ron 2             Diurno      261.30
# 6 Nafta (súper) entre 92 y 95 Ron 3             Nocturno    261.30
#   fecha_vigencia   idempresabandera empresabandera latitud   longitud
# 1 30/03/2019 14:00 28               PUMA           -38.03117 -57.57552
# 2 30/03/2019 14:00 28               PUMA           -38.03117 -57.57552
# 3 30/04/2019 20:00 28               PUMA           -38.03117 -57.57552
# 4 30/04/2019 20:00 28               PUMA           -38.03117 -57.57552
# 5 31/07/2023 22:00 28               PUMA           -38.03117 -57.57552
# 6 31/07/2023 22:00 28               PUMA           -38.03117 -57.57552
#   geojson
# 1 {"type":"Point","coordinates":[-57.575518,-38.031169]}
# 2 {"type":"Point","coordinates":[-57.575518,-38.031169]}
# 3 {"type":"Point","coordinates":[-57.575518,-38.031169]}
# 4 {"type":"Point","coordinates":[-57.575518,-38.031169]}
# 5 {"type":"Point","coordinates":[-57.575518,-38.031169]}
# 6 {"type":"Point","coordinates":[-57.575518,-38.031169]}

# %%
# vemos todos los productos que hay

unique(historicos$producto)
# Out:
# [1] "Gas Oil Grado 2"                  "Gas Oil Grado 3"
# [3] "GNC"                              "Nafta (premium) de más de 95 Ron"
# [5] "Nafta (súper) entre 92 y 95 Ron"

# %%
# eliminamos las columnas que no nos sirven y formateamos la fecha

historicos <- historicos %>%
    mutate(fecha = as.Date(fecha_vigencia, format = "%d/%m/%Y %H:%M")) %>%
    select(-empresa, -idempresa,-idproducto, -idtipohorario, -idempresabandera, -fecha_vigencia, -geojson) %>%
    distinct() %>%
    arrange(fecha)

# %%
# Nos fijamos la cantidad de datos por cada anio

historicos %>%
    mutate(anio = as.numeric(format(fecha, "%Y"))) %>%
    group_by(anio) %>%
    summarise(count = n()) %>%
    arrange(desc(count))
# Out:
#    anio count
# 1  2023 566706
# 2  2018 449171
# 3  2024 405077
# 4  2019 366471
# 5  2022 349490
# 6  2021 319342
# 7  2020 207973
# 8  2017 186933
# 9  2016    343
# 10 2013     34
# 11 2004     24
# 12 2002     22
# 13    2     18
# 14    6     16
# 15    4     12
# 16    8     12
# 17 2014     12
# 18 2001     10
# 19 2003     10
# 20 2015     10
# 21    3      8
# 22 2008      8
# 23    1      6
# 24    5      6
# 25  202      6
# 26 2005      6
# 27    7      4
# 28   19      4
# 29 2006      4
# 30 2009      4
# 31 2010      4
# 32 2012      4
# 33 2025      4
# 34 2029      4
# 35 2031      4
# 36 4201      4
# 37 2011      3
# 38   17      2
# 39   18      2
# 40   22      2
# 41   23      2
# 42  120      2
# 43  201      2
# 44  207      2
# 45 1157      2
# 46 1218      2
# 47 2007      2
# 48 2027      2
# 49 2030      2
# 50 3201      2
# 51 6202      2
# 52 7202      2
# 53 8202      2
# 54 9202      2
# 55 9920      2
# 56 2028      1
# 57 2044      1

# %%
# Eliminamos los registros antes del 2017 y despues del 2024 y los que tienen precio 0

historicos <- historicos %>%
    mutate(year = as.numeric(format(fecha, "%Y"))) %>%
    filter(year >= 2017 & year <= 2024 & precio > 0) %>%
    select(-year)

# %%
# nos fijamos si hay una diferencia significativa entre los precios diurnos y nocturnos

historicos %>%
    group_by(tipohorario) %>%
    summarise(prom = mean(precio))
# Out:
#   tipohorario prom
# 1 Diurno      270.1924
# 2 Nocturno    270.7199

# %%
# comprimimos cada registro de precio en un solo promedio entre los precios diurno y nocturno

historicos <- historicos %>%
    group_by(direccion, localidad, provincia, producto, empresabandera, latitud, longitud, fecha) %>%
    summarise(precio = mean(precio), .groups = "drop")

# %%
# graficamos para detectar outliers

ggplot(historicos, aes(x=fecha, y=precio, color=producto)) +
  geom_point() +
  labs(
    title='Precio a lo largo del tiempo',
    x='Tiempo',
    y="Precio"
  ) +
    theme_classic()
# Out:
# plot without title

# %%
# eliminamos los outliers severos

historicos <- historicos %>%
    mutate(anio = year(fecha), mes = month(fecha)) %>%
    group_by(producto, provincia, anio, mes) %>%
    mutate(
        Q1 = quantile(precio, 0.25),
        Q3 = quantile(precio, 0.75),
        IQR = Q3 - Q1,
        lower_limit = Q1 - 3 * IQR,
        upper_limit = Q3 + 3 * IQR
    ) %>%
    filter(precio >= lower_limit & precio <= upper_limit) %>%
    select(-Q1, -Q3, -IQR, -lower_limit, -upper_limit) %>%
    ungroup()

historicos <- historicos %>%
    select(-anio, -mes) %>%
    arrange(fecha)

# %%
# graficamos devuelta para detectar outliers residuales

ggplot(historicos, aes(x=fecha, y=precio, color=producto)) +
  geom_point() +
  labs(
    title='Precio a lo largo del tiempo',
    x='Tiempo',
    y="Precio"
  ) +
    theme_classic()
# Out:
# plot without title

# %%
# eliminamos los outliers residuales

historicos <- historicos %>%
    filter( !((year(fecha) == 2021 & precio > 250) | (year(fecha) == 2020 & precio > 100)))

# %%
head(historicos)
# Out:
#   direccion         localidad     provincia    producto
# 1 12 DE OCTUBRE 539 JACINTO ARAUZ LA PAMPA     Gas Oil Grado 2
# 2 12 DE OCTUBRE 539 JACINTO ARAUZ LA PAMPA     Gas Oil Grado 3
# 3 12 DE OCTUBRE 539 JACINTO ARAUZ LA PAMPA     Nafta (súper) entre 92 y 95 Ron
# 4 13 1398           LA PLATA      BUENOS AIRES GNC
# 5 13 1398           LA PLATA      BUENOS AIRES Nafta (súper) entre 92 y 95 Ron
# 6 44 Y 159          LA PLATA      BUENOS AIRES GNC
#   empresabandera latitud   longitud  fecha      precio
# 1 BLANCA         -38.08858 -63.42783 2017-01-01 15.900
# 2 BLANCA         -38.08858 -63.42783 2017-01-01 18.500
# 3 BLANCA         -38.08858 -63.42783 2017-01-01 15.500
# 4 GULF           -34.93582 -57.93558 2017-01-01  9.999
# 5 GULF           -34.93582 -57.93558 2017-01-01 21.850
# 6 BLANCA         -34.95986 -58.00878 2017-01-01  9.150

# %%
str(historicos)
# Out:
# tibble [1,375,915 × 9] (S3: tbl_df/tbl/data.frame)
#  $ direccion     : chr [1:1375915] "12 DE OCTUBRE 539" "12 DE OCTUBRE 539" "12 DE OCTUBRE 539" "13 1398" ...
#  $ localidad     : chr [1:1375915] "JACINTO ARAUZ" "JACINTO ARAUZ" "JACINTO ARAUZ" "LA PLATA" ...
#  $ provincia     : chr [1:1375915] "LA PAMPA" "LA PAMPA" "LA PAMPA" "BUENOS AIRES" ...
#  $ producto      : chr [1:1375915] "Gas Oil Grado 2" "Gas Oil Grado 3" "Nafta (súper) entre 92 y 95 Ron" "GNC" ...
#  $ empresabandera: chr [1:1375915] "BLANCA" "BLANCA" "BLANCA" "GULF" ...
#  $ latitud       : num [1:1375915] -38.1 -38.1 -38.1 -34.9 -34.9 ...
#  $ longitud      : num [1:1375915] -63.4 -63.4 -63.4 -57.9 -57.9 ...
#  $ fecha         : Date[1:1375915], format: "2017-01-01" "2017-01-01" ...
#  $ precio        : num [1:1375915] 15.9 18.5 15.5 10 21.9 ...

# %%
write_parquet(historicos, 'surtidor_historicos.parquet')

# %%
write_csv_arrow(historicos, 'surtidor_historicos.csv')
